# %% [markdown]
# # 📌 Cell 1. Environment setup

# %%
import os
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.2f}".format)

# %% [markdown]
# # 📌 Cell 2. File check

# %%
file_path = "2019-Oct.csv"

# File exists
os.path.exists(file_path)
# Out:
# True

# %%
# File size (MB)
os.path.getsize(file_path) / 1024**2
# Out:
# 5406.010489463806

# %% [markdown]
# # 📌 Cell 3. Load data (sample)

# %%
df = pd.read_csv(
    file_path,
    nrows=100_000
)

# %% [markdown]
# # 📌 Cell 4. Check data shape

# %%
df.shape
# Out:
# (100000, 9)

# %% [markdown]
# # 📌 Cell 5. Check schema (columns)

# %%
df.columns
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='str')
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # 📌 Cell 6. Preview sample data

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand   price    user_id  \
# 0                                  NaN  shiseido   35.79  541312140
# 1  appliances.environment.water_heater      aqua   33.20  554748717
# 2           furniture.living_room.sofa       NaN  543.10  519107250
# 3                   computers.notebook    lenovo  251.74  550050854
# 4               electronics.smartphone     apple 1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
df.tail()
# Out:
#                     event_time event_type  product_id          category_id  \
# 99995  2019-10-01 04:28:27 UTC       view    17300136  2053013553853497655
# 99996  2019-10-01 04:28:27 UTC       view     2601810  2053013563970159485
# 99997  2019-10-01 04:28:27 UTC       view     1306100  2053013558920217191
# 99998  2019-10-01 04:28:27 UTC       view     3200549  2053013555321504139
# 99999  2019-10-01 04:28:27 UTC       view     6200949  2053013552293216471
#
#                            category_code     brand   price    user_id  \
# 99995                                NaN   montale  102.96  515593818
# 99996                                NaN     artel  155.29  530821477
# 99997                 computers.notebook    xiaomi 1029.60  521314335
# 99998    appliances.kitchen.meat_grinder  dauscher   25.71  555131253
# 99999  appliances.environment.air_heater       NaN   10.17  523211916
#
#                                user_session
# 99995  96d3640f-9d00-4b69-a4d8-ca581c1677d3
# ...

# %% [markdown]
# # 📌 Cell 7. Check data types

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     100000 non-null  str
#  1   event_type     100000 non-null  str
#  2   product_id     100000 non-null  int64
#  3   category_id    100000 non-null  int64
#  4   category_code  67413 non-null   str
#  5   brand          85607 non-null   str
#  6   price          100000 non-null  float64
#  7   user_id        100000 non-null  int64
#  8   user_session   100000 non-null  str
# dtypes: float64(1), int64(3), str(5)
# memory usage: 6.9 MB

# %% [markdown]
# # 📌 Cell 8. Check missing values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# category_code    32587
# brand            14393
# event_time           0
# product_id           0
# event_type           0
# category_id          0
# price                0
# user_id              0
# user_session         0
# dtype: int64

# %% [markdown]
# # 📌 Cell 9. Basic stats / outlier check

# %%
df.describe()
# Out:
#        product_id            category_id     price      user_id
# count   100000.00              100000.00 100000.00    100000.00
# mean  10298188.21 2056093711486667264.00    286.83 531090895.65
# std   11135458.34   14909815920515066.00    360.30  16620297.33
# min    1001588.00 2053013552226107648.00      0.00 306441847.00
# 25%    1005124.00 2053013555287949824.00     61.01 515636023.00
# 50%    5100579.50 2053013555631882752.00    154.38 526964945.00
# 75%   15901690.50 2053013562611204864.00    357.11 547718922.00
# max   53100015.00 2175419595093967616.00   2574.07 555483540.00

# %%
df.describe(include="string")
# Out:
#                      event_time event_type           category_code    brand  \
# count                    100000     100000                   67413    85607
# unique                     8753          3                     123     1506
# top     2019-10-01 04:05:18 UTC       view  electronics.smartphone  samsung
# freq                         34      97130                   26738    11683
#
#                                 user_session
# count                                 100000
# unique                                 24382
# top     dab9fcec-5ecd-428a-914d-d60f3f73d32c
# freq                                     113

# %% [markdown]
# # 📌 Cell 10. Check duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %% [markdown]
# # 📌 Cell 11. Unique values by column (meaning check)

# %%
df.nunique().sort_values()
# Out:
# event_type           3
# category_code      123
# category_id        509
# brand             1506
# price             8014
# event_time        8753
# user_id          20384
# product_id       20621
# user_session     24382
# dtype: int64

# %% [markdown]
# # 📌 Cell 12. Extract summary (Markdown)

# %% [markdown]
# ### Extract EDA Summary
#
# - Data: E-commerce event log (sample 100k rows)
# - Columns: 9
# - event_time: string → needs datetime conversion
# - category_code, brand: missing values present (business-specific)
# - price: includes zeros → needs handling policy
# - event_type: view share is very high
# - Duplicates: very few (17 rows)
# - Next steps: type casting, missing-value policy, feature separation
